# %%
import pandas as pd
import warnings
from pmdarima import auto_arima
from datetime import datetime, timedelta
import json

# %%
file_path = "../Data/Interim/cleaned_food_prices.csv"
df_range = pd.read_csv(file_path)

#dropping columns related to food price index
df_nofpi_range = df_range.drop(columns=['o_food_price_index', 'h_food_price_index', 'l_food_price_index', 'c_food_price_index', 'inflation_food_price_index', 'trust_food_price_index'])

# Convert 'Date' column to datetime format
df_nofpi_range['Date'] = pd.to_datetime(df_nofpi_range['Date'])

#dropping columns related to inflation
df_noinf_range = df_nofpi_range.drop(columns=['inflation_beans','inflation_cabbage', 'inflation_carrots', 'inflation_eggs', 'inflation_meat_beef_chops', 'inflation_meat_chicken_whole', 'inflation_meat_pork', 'inflation_onions', 'inflation_potatoes', 'inflation_rice', 'inflation_tomatoes'])

#dropping columns related to trust scores
df_cleaned_range = df_noinf_range.drop(columns=['trust_beans','trust_cabbage', 'trust_carrots', 'trust_eggs', 'trust_meat_beef_chops', 'trust_meat_chicken_whole', 'trust_meat_pork', 'trust_onions', 'trust_potatoes', 'trust_rice', 'trust_tomatoes'])

#dropping uneeded columns
df_unneeded_range = df_cleaned_range.drop(columns=['country', 'City', 'lat', 'lon', 'Province', 'year', 'month'])

# Reshaping from wide to long format (including year and month as part of the identifier)
df_range = df_unneeded_range.melt(id_vars=['Region', 'Date'], var_name='Food_Items', value_name='Price')

df_range_filtered = df_range[df_range['Food_Items'].str.startswith('c_')]

df_range_filtered.loc[:, 'Food_Items'] = df_range_filtered['Food_Items'].str.replace('c_', '', regex=True)

# Sort by date
dfml = df_range_filtered.sort_values(by=['Region', 'Date'])

# %%
# Suppress warnings
warnings.filterwarnings("ignore")

def preprocess_data(df, region, item):
    """Preprocess data for a specific region and item."""
    region_df = df[(df['Region'] == region) & (df['Food_Items'] == item)]
    region_df = (
        region_df.groupby('Date', as_index=False)['Price']
        .mean()  # Aggregate duplicate dates by averaging
    )
    region_df = region_df.set_index('Date').asfreq('MS')  # Ensure monthly frequency
    region_df['Price'] = region_df['Price'].interpolate()  # Fill missing values
    return region_df

def generate_forecast_with_params(df, region, item):
    """Generate forecast with extended parameter search."""
    region_df = preprocess_data(df, region, item)
    
    if len(region_df) < 12:
        return None
    
    try:
        # Fit ARIMA model with extended parameter search
        model = auto_arima(region_df['Price'],
                          start_p=0, max_p=10,
                          start_d=0, max_d=10,
                          start_q=0, max_q=10,
                          seasonal=True,
                          m=12,
                          stepwise=False,  # Use complete grid search
                          trace=True,
                          n_jobs=-1,
                          error_action='ignore',
                          suppress_warnings=True)
        
        # Generate forecast
        forecast = model.predict(n_periods=36)
        
        # Get model order
        order = model.order
        seasonal_order = model.seasonal_order
        
        # Create future dates
        last_date = region_df.index[-1]
        future_dates = pd.date_range(start=last_date + pd.DateOffset(months=1), 
                                   periods=36, freq='MS')
        
        # Create results dictionary
        results = {
            'region': region,
            'item': item,
            'historical_dates': region_df.index.strftime('%Y-%m-%d').tolist(),
            'historical_values': region_df['Price'].tolist(),
            'forecast_dates': future_dates.strftime('%Y-%m-%d').tolist(),
            'forecast_values': forecast.tolist(),
            'p': order[0],
            'd': order[1],
            'q': order[2],
            'P': seasonal_order[0],
            'D': seasonal_order[1],
            'Q': seasonal_order[2],
            'aic': model.aic()
        }
        
        return results
    
    except Exception as e:
        print(f"Error generating forecast for {region} - {item}: {str(e)}")
        return None

def save_forecasts(df, output_file='forecasts.csv'):
    """Generate and save forecasts for all combinations."""
    regions = sorted(df['Region'].unique())
    items = sorted(df['Food_Items'].unique())
    
    all_forecasts = []
    
    for region in regions:
        for item in items:
            print(f"Processing {region} - {item}")
            forecast = generate_forecast_with_params(df, region, item)
            
            if forecast:
                # Flatten the forecast data for CSV storage
                forecast_row = {
                    'region': region,
                    'item': item,
                    'historical_dates': json.dumps(forecast['historical_dates']),
                    'historical_values': json.dumps(forecast['historical_values']),
                    'forecast_dates': json.dumps(forecast['forecast_dates']),
                    'forecast_values': json.dumps(forecast['forecast_values']),
                    'p': forecast['p'],
                    'd': forecast['d'],
                    'q': forecast['q'],
                    'P': forecast['P'],
                    'D': forecast['D'],
                    'Q': forecast['Q'],
                    'aic': forecast['aic']
                }
                all_forecasts.append(forecast_row)
    
    # Convert to DataFrame and save
    forecasts_df = pd.DataFrame(all_forecasts)
    forecasts_df.to_csv(output_file, index=False)
    print(f"Forecasts saved to {output_file}")

# Example usage:
if __name__ == "__main__":
    
     save_forecasts(dfml, 'forecasts.csv')
# Out:
# Processing Autonomous region in Muslim Mindanao - beans
#
# Best model:  ARIMA(3,1,2)(0,0,0)[12] intercept
# Total fit time: 15.297 seconds
# Processing Autonomous region in Muslim Mindanao - cabbage
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 7.564 seconds
# Processing Autonomous region in Muslim Mindanao - carrots
#
# Best model:  ARIMA(2,1,1)(0,0,0)[12] intercept
# Total fit time: 9.199 seconds
# Processing Autonomous region in Muslim Mindanao - eggs
#
# Best model:  ARIMA(0,1,5)(0,0,0)[12] intercept
# Total fit time: 11.228 seconds
# Processing Autonomous region in Muslim Mindanao - meat_beef_chops
#
# Best model:  ARIMA(1,2,2)(0,0,0)[12]
# Total fit time: 7.077 seconds
# Processing Autonomous region in Muslim Mindanao - meat_chicken_whole
#
# Best model:  ARIMA(3,1,0)(0,0,0)[12] intercept
# Total fit time: 7.021 seconds
# Processing Autonomous region in Muslim Mindanao - meat_pork
#
# Best model:  ARIMA(2,1,2)(1,0,0)[12] intercept
# Total fit time: 6.435 seconds
# Processing Autonomous region in Muslim Mindanao - onions
#
# Best model:  ARIMA(1,1,3)(0,0,0)[12] intercept
# Total fit time: 7.687 seconds
# Processing Autonomous region in Muslim Mindanao - potatoes
#
# Best model:  ARIMA(3,1,0)(0,0,2)[12] intercept
# Total fit time: 8.132 seconds
# Processing Autonomous region in Muslim Mindanao - rice
#
# Best model:  ARIMA(4,1,0)(0,0,0)[12] intercept
# Total fit time: 8.511 seconds
# Processing Autonomous region in Muslim Mindanao - tomatoes
#
# Best model:  ARIMA(2,1,1)(2,0,0)[12] intercept
# Total fit time: 5.465 seconds
# Processing Cordillera Administrative region - beans
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 5.986 seconds
# Processing Cordillera Administrative region - cabbage
#
# Best model:  ARIMA(0,1,4)(0,0,0)[12] intercept
# Total fit time: 7.991 seconds
# Processing Cordillera Administrative region - carrots
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 7.064 seconds
# Processing Cordillera Administrative region - eggs
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 9.956 seconds
# Processing Cordillera Administrative region - meat_beef_chops
#
# Best model:  ARIMA(1,2,1)(1,0,0)[12]
# Total fit time: 6.599 seconds
# Processing Cordillera Administrative region - meat_chicken_whole
#
# Best model:  ARIMA(3,1,1)(1,0,0)[12] intercept
# Total fit time: 7.434 seconds
# Processing Cordillera Administrative region - meat_pork
#
# Best model:  ARIMA(2,1,0)(0,0,2)[12] intercept
# Total fit time: 6.260 seconds
# Processing Cordillera Administrative region - onions
#
# Best model:  ARIMA(2,1,1)(1,0,0)[12] intercept
# Total fit time: 8.721 seconds
# Processing Cordillera Administrative region - potatoes
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 7.390 seconds
# Processing Cordillera Administrative region - rice
#
# Best model:  ARIMA(3,1,2)(0,0,0)[12] intercept
# Total fit time: 7.136 seconds
# Processing Cordillera Administrative region - tomatoes
#
# Best model:  ARIMA(2,1,3)(0,0,0)[12] intercept
# Total fit time: 7.399 seconds
# Processing Market Average - beans
#
# Best model:  ARIMA(1,1,3)(0,0,0)[12] intercept
# Total fit time: 7.354 seconds
# Processing Market Average - cabbage
#
# Best model:  ARIMA(0,1,3)(0,0,0)[12] intercept
# Total fit time: 10.242 seconds
# Processing Market Average - carrots
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 9.218 seconds
# Processing Market Average - eggs
#
# Best model:  ARIMA(2,1,2)(1,0,0)[12] intercept
# Total fit time: 9.417 seconds
# Processing Market Average - meat_beef_chops
#
# Best model:  ARIMA(1,1,0)(1,0,0)[12] intercept
# Total fit time: 8.133 seconds
# Processing Market Average - meat_chicken_whole
#
# Best model:  ARIMA(1,1,0)(2,0,1)[12] intercept
# Total fit time: 7.285 seconds
# Processing Market Average - meat_pork
#
# Best model:  ARIMA(5,1,0)(0,0,0)[12] intercept
# Total fit time: 7.539 seconds
# Processing Market Average - onions
#
# Best model:  ARIMA(0,1,5)(0,0,0)[12] intercept
# Total fit time: 7.664 seconds
# Processing Market Average - potatoes
#
# Best model:  ARIMA(3,1,1)(1,0,0)[12] intercept
# Total fit time: 7.132 seconds
# Processing Market Average - rice
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 7.943 seconds
# Processing Market Average - tomatoes
#
# Best model:  ARIMA(1,1,4)(0,0,0)[12] intercept
# Total fit time: 8.341 seconds
# Processing National Capital region - beans
#
# Best model:  ARIMA(0,1,2)(0,0,0)[12] intercept
# Total fit time: 10.149 seconds
# Processing National Capital region - cabbage
#
# Best model:  ARIMA(2,1,3)(0,0,0)[12] intercept
# Total fit time: 9.557 seconds
# Processing National Capital region - carrots
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 9.436 seconds
# Processing National Capital region - eggs
#
# Best model:  ARIMA(5,1,0)(0,0,0)[12] intercept
# Total fit time: 10.915 seconds
# Processing National Capital region - meat_beef_chops
#
# Best model:  ARIMA(2,1,1)(0,0,2)[12] intercept
# Total fit time: 8.260 seconds
# Processing National Capital region - meat_chicken_whole
#
# Best model:  ARIMA(1,1,2)(0,0,0)[12] intercept
# Total fit time: 8.589 seconds
# Processing National Capital region - meat_pork
#
# Best model:  ARIMA(5,1,0)(0,0,0)[12] intercept
# Total fit time: 8.715 seconds
# Processing National Capital region - onions
#
# Best model:  ARIMA(0,1,2)(0,0,2)[12] intercept
# Total fit time: 7.959 seconds
# Processing National Capital region - potatoes
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 7.200 seconds
# Processing National Capital region - rice
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12] intercept
# Total fit time: 6.458 seconds
# Processing National Capital region - tomatoes
#
# Best model:  ARIMA(1,1,1)(2,0,1)[12] intercept
# Total fit time: 9.906 seconds
# Processing Region I - beans
#
# Best model:  ARIMA(3,1,0)(0,0,0)[12] intercept
# Total fit time: 6.377 seconds
# Processing Region I - cabbage
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 7.595 seconds
# Processing Region I - carrots
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 7.667 seconds
# Processing Region I - eggs
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 9.027 seconds
# Processing Region I - meat_beef_chops
#
# Best model:  ARIMA(0,2,1)(0,0,1)[12]
# Total fit time: 7.139 seconds
# Processing Region I - meat_chicken_whole
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12] intercept
# Total fit time: 6.594 seconds
# Processing Region I - meat_pork
#
# Best model:  ARIMA(3,1,2)(0,0,0)[12] intercept
# Total fit time: 6.371 seconds
# Processing Region I - onions
#
# Best model:  ARIMA(0,1,3)(2,0,0)[12] intercept
# Total fit time: 7.217 seconds
# Processing Region I - potatoes
#
# Best model:  ARIMA(5,1,0)(0,0,0)[12] intercept
# Total fit time: 7.736 seconds
# Processing Region I - rice
#
# Best model:  ARIMA(2,1,2)(1,0,0)[12] intercept
# Total fit time: 6.504 seconds
# Processing Region I - tomatoes
#
# Best model:  ARIMA(2,1,1)(0,0,0)[12] intercept
# Total fit time: 6.351 seconds
# Processing Region II - beans
#
# Best model:  ARIMA(4,1,1)(0,0,0)[12] intercept
# Total fit time: 5.937 seconds
# Processing Region II - cabbage
#
# Best model:  ARIMA(4,1,1)(0,0,0)[12] intercept
# Total fit time: 7.369 seconds
# Processing Region II - carrots
#
# Best model:  ARIMA(4,1,1)(0,0,0)[12] intercept
# Total fit time: 7.734 seconds
# Processing Region II - eggs
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 8.218 seconds
# Processing Region II - meat_beef_chops
#
# Best model:  ARIMA(1,2,1)(1,0,0)[12]
# Total fit time: 5.809 seconds
# Processing Region II - meat_chicken_whole
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 6.715 seconds
# Processing Region II - meat_pork
#
# Best model:  ARIMA(1,1,2)(2,0,0)[12] intercept
# Total fit time: 5.714 seconds
# Processing Region II - onions
#
# Best model:  ARIMA(2,1,1)(1,0,0)[12] intercept
# Total fit time: 7.374 seconds
# Processing Region II - potatoes
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 5.993 seconds
# Processing Region II - rice
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 6.062 seconds
# Processing Region II - tomatoes
#
# Best model:  ARIMA(2,1,1)(2,0,0)[12] intercept
# Total fit time: 7.028 seconds
# Processing Region III - beans
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12] intercept
# Total fit time: 6.129 seconds
# Processing Region III - cabbage
#
# Best model:  ARIMA(2,1,1)(0,0,2)[12] intercept
# Total fit time: 6.232 seconds
# Processing Region III - carrots
#
# Best model:  ARIMA(2,1,1)(2,0,0)[12] intercept
# Total fit time: 6.590 seconds
# Processing Region III - eggs
#
# Best model:  ARIMA(2,1,2)(1,0,0)[12] intercept
# Total fit time: 8.057 seconds
# Processing Region III - meat_beef_chops
#
# Best model:  ARIMA(0,1,2)(1,0,0)[12] intercept
# Total fit time: 6.724 seconds
# Processing Region III - meat_chicken_whole
#
# Best model:  ARIMA(0,1,5)(0,0,0)[12] intercept
# Total fit time: 6.525 seconds
# Processing Region III - meat_pork
#
# Best model:  ARIMA(3,1,2)(0,0,0)[12] intercept
# Total fit time: 7.276 seconds
# Processing Region III - onions
#
# Best model:  ARIMA(2,1,1)(0,0,2)[12] intercept
# Total fit time: 7.352 seconds
# Processing Region III - potatoes
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 6.114 seconds
# Processing Region III - rice
#
# Best model:  ARIMA(1,1,4)(0,0,0)[12] intercept
# Total fit time: 7.078 seconds
# Processing Region III - tomatoes
#
# Best model:  ARIMA(2,1,2)(0,0,1)[12] intercept
# Total fit time: 8.371 seconds
# Processing Region IV-A - beans
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12] intercept
# Total fit time: 8.349 seconds
# Processing Region IV-A - cabbage
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 8.161 seconds
# Processing Region IV-A - carrots
#
# Best model:  ARIMA(3,1,1)(1,0,0)[12] intercept
# Total fit time: 8.987 seconds
# Processing Region IV-A - eggs
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 9.405 seconds
# Processing Region IV-A - meat_beef_chops
#
# Best model:  ARIMA(2,1,0)(0,0,0)[12] intercept
# Total fit time: 8.006 seconds
# Processing Region IV-A - meat_chicken_whole
#
# Best model:  ARIMA(2,1,1)(0,0,2)[12] intercept
# Total fit time: 6.586 seconds
# Processing Region IV-A - meat_pork
#
# Best model:  ARIMA(0,1,4)(0,0,0)[12] intercept
# Total fit time: 7.772 seconds
# Processing Region IV-A - onions
#
# Best model:  ARIMA(3,1,0)(1,0,1)[12] intercept
# Total fit time: 9.177 seconds
# Processing Region IV-A - potatoes
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 7.514 seconds
# Processing Region IV-A - rice
#
# Best model:  ARIMA(2,1,0)(0,0,0)[12] intercept
# Total fit time: 6.070 seconds
# Processing Region IV-A - tomatoes
#
# Best model:  ARIMA(2,1,1)(0,0,2)[12] intercept
# Total fit time: 7.989 seconds
# Processing Region IV-B - beans
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12] intercept
# Total fit time: 8.330 seconds
# Processing Region IV-B - cabbage
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 8.947 seconds
# Processing Region IV-B - carrots
#
# Best model:  ARIMA(2,1,2)(1,0,0)[12] intercept
# Total fit time: 8.129 seconds
# Processing Region IV-B - eggs
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 9.865 seconds
# Processing Region IV-B - meat_beef_chops
#
# Best model:  ARIMA(0,2,5)(0,0,0)[12]
# Total fit time: 7.271 seconds
# Processing Region IV-B - meat_chicken_whole
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12] intercept
# Total fit time: 7.008 seconds
# Processing Region IV-B - meat_pork
#
# Best model:  ARIMA(0,2,5)(0,0,0)[12]
# Total fit time: 6.846 seconds
# Processing Region IV-B - onions
#
# Best model:  ARIMA(3,1,0)(1,0,1)[12] intercept
# Total fit time: 8.382 seconds
# Processing Region IV-B - potatoes
#
# Best model:  ARIMA(3,1,0)(0,0,2)[12] intercept
# Total fit time: 7.860 seconds
# Processing Region IV-B - rice
#
# Best model:  ARIMA(2,1,0)(0,0,0)[12] intercept
# Total fit time: 9.086 seconds
# Processing Region IV-B - tomatoes
#
# Best model:  ARIMA(2,1,1)(0,0,0)[12] intercept
# Total fit time: 8.203 seconds
# Processing Region IX - beans
#
# Best model:  ARIMA(1,1,0)(1,0,1)[12] intercept
# Total fit time: 7.039 seconds
# Processing Region IX - cabbage
#
# Best model:  ARIMA(2,1,2)(1,0,0)[12] intercept
# Total fit time: 8.383 seconds
# Processing Region IX - carrots
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 7.756 seconds
# Processing Region IX - eggs
#
# Best model:  ARIMA(2,1,3)(0,0,0)[12] intercept
# Total fit time: 10.939 seconds
# Processing Region IX - meat_beef_chops
#
# Best model:  ARIMA(2,2,1)(0,0,0)[12]
# Total fit time: 7.168 seconds
# Processing Region IX - meat_chicken_whole
#
# Best model:  ARIMA(0,1,4)(0,0,0)[12] intercept
# Total fit time: 7.985 seconds
# Processing Region IX - meat_pork
#
# Best model:  ARIMA(3,1,2)(0,0,0)[12] intercept
# Total fit time: 7.183 seconds
# Processing Region IX - onions
#
# Best model:  ARIMA(0,1,2)(1,0,1)[12] intercept
# Total fit time: 8.418 seconds
# Processing Region IX - potatoes
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 7.020 seconds
# Processing Region IX - rice
#
# Best model:  ARIMA(2,1,3)(0,0,0)[12] intercept
# Total fit time: 8.295 seconds
# Processing Region IX - tomatoes
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 8.588 seconds
# Processing Region V - beans
#
# Best model:  ARIMA(3,1,0)(0,0,0)[12] intercept
# Total fit time: 7.070 seconds
# Processing Region V - cabbage
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 8.869 seconds
# Processing Region V - carrots
#
# Best model:  ARIMA(2,1,2)(0,0,1)[12] intercept
# Total fit time: 9.777 seconds
# Processing Region V - eggs
#
# Best model:  ARIMA(5,1,0)(0,0,0)[12] intercept
# Total fit time: 10.660 seconds
# Processing Region V - meat_beef_chops
#
# Best model:  ARIMA(2,1,0)(0,0,0)[12] intercept
# Total fit time: 7.802 seconds
# Processing Region V - meat_chicken_whole
#
# Best model:  ARIMA(0,1,4)(0,0,0)[12] intercept
# Total fit time: 6.739 seconds
# Processing Region V - meat_pork
#
# Best model:  ARIMA(3,1,2)(0,0,0)[12] intercept
# Total fit time: 8.069 seconds
# Processing Region V - onions
#
# Best model:  ARIMA(2,1,3)(0,0,0)[12] intercept
# Total fit time: 9.118 seconds
# Processing Region V - potatoes
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 7.662 seconds
# Processing Region V - rice
#
# Best model:  ARIMA(0,1,2)(0,0,0)[12] intercept
# Total fit time: 8.543 seconds
# Processing Region V - tomatoes
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 7.702 seconds
# Processing Region VI - beans
#
# Best model:  ARIMA(0,1,4)(0,0,0)[12] intercept
# Total fit time: 6.942 seconds
# Processing Region VI - cabbage
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 8.532 seconds
# Processing Region VI - carrots
#
# Best model:  ARIMA(3,1,1)(0,0,1)[12] intercept
# Total fit time: 9.133 seconds
# Processing Region VI - eggs
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 8.877 seconds
# Processing Region VI - meat_beef_chops
#
# Best model:  ARIMA(3,2,2)(0,0,0)[12]
# Total fit time: 7.760 seconds
# Processing Region VI - meat_chicken_whole
#
# Best model:  ARIMA(1,1,0)(1,0,1)[12] intercept
# Total fit time: 7.584 seconds
# Processing Region VI - meat_pork
#
# Best model:  ARIMA(0,1,3)(1,0,1)[12] intercept
# Total fit time: 7.495 seconds
# Processing Region VI - onions
#
# Best model:  ARIMA(2,1,1)(1,0,0)[12] intercept
# Total fit time: 8.613 seconds
# Processing Region VI - potatoes
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 8.500 seconds
# Processing Region VI - rice
#
# Best model:  ARIMA(0,1,2)(0,0,0)[12] intercept
# Total fit time: 7.743 seconds
# Processing Region VI - tomatoes
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 6.946 seconds
# Processing Region VII - beans
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12] intercept
# Total fit time: 6.563 seconds
# Processing Region VII - cabbage
#
# Best model:  ARIMA(3,1,2)(0,0,0)[12] intercept
# Total fit time: 8.131 seconds
# Processing Region VII - carrots
#
# Best model:  ARIMA(2,1,1)(0,0,0)[12] intercept
# Total fit time: 7.962 seconds
# Processing Region VII - eggs
#
# Best model:  ARIMA(0,1,2)(0,0,2)[12] intercept
# Total fit time: 9.709 seconds
# Processing Region VII - meat_beef_chops
#
# Best model:  ARIMA(0,2,3)(1,0,0)[12]
# Total fit time: 5.982 seconds
# Processing Region VII - meat_chicken_whole
#
# Best model:  ARIMA(4,1,0)(1,0,0)[12] intercept
# Total fit time: 8.232 seconds
# Processing Region VII - meat_pork
#
# Best model:  ARIMA(5,1,0)(0,0,0)[12] intercept
# Total fit time: 5.506 seconds
# Processing Region VII - onions
#
# Best model:  ARIMA(2,1,0)(1,0,2)[12] intercept
# Total fit time: 7.613 seconds
# Processing Region VII - potatoes
#
# Best model:  ARIMA(2,1,1)(2,0,0)[12] intercept
# Total fit time: 6.109 seconds
# Processing Region VII - rice
#
# Best model:  ARIMA(3,1,2)(0,0,0)[12] intercept
# Total fit time: 6.653 seconds
# Processing Region VII - tomatoes
#
# Best model:  ARIMA(2,1,1)(1,0,0)[12] intercept
# Total fit time: 7.588 seconds
# Processing Region VIII - beans
#
# Best model:  ARIMA(1,1,1)(0,0,0)[12] intercept
# Total fit time: 6.232 seconds
# Processing Region VIII - cabbage
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 8.043 seconds
# Processing Region VIII - carrots
#
# Best model:  ARIMA(2,1,3)(0,0,0)[12] intercept
# Total fit time: 6.667 seconds
# Processing Region VIII - eggs
#
# Best model:  ARIMA(3,1,0)(0,0,2)[12] intercept
# Total fit time: 7.496 seconds
# Processing Region VIII - meat_beef_chops
#
# Best model:  ARIMA(0,2,1)(0,0,0)[12]
# Total fit time: 5.774 seconds
# Processing Region VIII - meat_chicken_whole
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 5.572 seconds
# Processing Region VIII - meat_pork
#
# Best model:  ARIMA(2,1,2)(1,0,0)[12] intercept
# Total fit time: 5.820 seconds
# Processing Region VIII - onions
#
# Best model:  ARIMA(2,1,1)(0,0,2)[12] intercept
# Total fit time: 6.337 seconds
# Processing Region VIII - potatoes
#
# Best model:  ARIMA(2,1,1)(2,0,0)[12] intercept
# Total fit time: 5.720 seconds
# Processing Region VIII - rice
#
# Best model:  ARIMA(1,1,3)(0,0,0)[12] intercept
# Total fit time: 5.443 seconds
# Processing Region VIII - tomatoes
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 7.059 seconds
# Processing Region X - beans
#
# Best model:  ARIMA(1,1,0)(0,0,2)[12] intercept
# Total fit time: 5.707 seconds
# Processing Region X - cabbage
#
# Best model:  ARIMA(0,1,5)(0,0,0)[12] intercept
# Total fit time: 6.833 seconds
# Processing Region X - carrots
#
# Best model:  ARIMA(2,1,1)(0,0,0)[12] intercept
# Total fit time: 6.059 seconds
# Processing Region X - eggs
#
# Best model:  ARIMA(1,1,2)(0,0,0)[12] intercept
# Total fit time: 8.036 seconds
# Processing Region X - meat_beef_chops
#
# Best model:  ARIMA(1,1,3)(0,0,0)[12] intercept
# Total fit time: 6.767 seconds
# Processing Region X - meat_chicken_whole
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 5.907 seconds
# Processing Region X - meat_pork
#
# Best model:  ARIMA(0,1,3)(0,0,1)[12] intercept
# Total fit time: 6.792 seconds
# Processing Region X - onions
#
# Best model:  ARIMA(0,1,5)(0,0,0)[12] intercept
# Total fit time: 8.815 seconds
# Processing Region X - potatoes
#
# Best model:  ARIMA(0,1,5)(0,0,0)[12] intercept
# Total fit time: 7.065 seconds
# Processing Region X - rice
#
# Best model:  ARIMA(2,1,2)(1,0,0)[12] intercept
# Total fit time: 6.292 seconds
# Processing Region X - tomatoes
#
# Best model:  ARIMA(2,1,1)(0,0,0)[12] intercept
# Total fit time: 6.812 seconds
# Processing Region XI - beans
#
# Best model:  ARIMA(0,1,2)(0,0,0)[12] intercept
# Total fit time: 6.044 seconds
# Processing Region XI - cabbage
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 7.326 seconds
# Processing Region XI - carrots
#
# Best model:  ARIMA(2,1,1)(0,0,1)[12] intercept
# Total fit time: 6.509 seconds
# Processing Region XI - eggs
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 8.896 seconds
# Processing Region XI - meat_beef_chops
#
# Best model:  ARIMA(2,2,1)(0,0,0)[12]
# Total fit time: 6.478 seconds
# Processing Region XI - meat_chicken_whole
#
# Best model:  ARIMA(3,1,1)(0,0,0)[12] intercept
# Total fit time: 6.463 seconds
# Processing Region XI - meat_pork
#
# Best model:  ARIMA(3,1,2)(0,0,0)[12] intercept
# Total fit time: 6.374 seconds
# Processing Region XI - onions
#
# Best model:  ARIMA(2,1,1)(0,0,0)[12] intercept
# Total fit time: 7.727 seconds
# Processing Region XI - potatoes
#
# Best model:  ARIMA(2,1,2)(0,0,1)[12] intercept
# Total fit time: 6.688 seconds
# Processing Region XI - rice
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 6.180 seconds
# Processing Region XI - tomatoes
#
# Best model:  ARIMA(0,1,4)(0,0,0)[12] intercept
# Total fit time: 6.575 seconds
# Processing Region XII - beans
#
# Best model:  ARIMA(2,1,3)(0,0,0)[12] intercept
# Total fit time: 6.105 seconds
# Processing Region XII - cabbage
#
# Best model:  ARIMA(0,1,5)(0,0,0)[12] intercept
# Total fit time: 6.882 seconds
# Processing Region XII - carrots
#
# Best model:  ARIMA(2,1,1)(0,0,0)[12] intercept
# Total fit time: 6.510 seconds
# Processing Region XII - eggs
#
# Best model:  ARIMA(3,1,0)(0,0,2)[12] intercept
# Total fit time: 9.092 seconds
# Processing Region XII - meat_beef_chops
#
# Best model:  ARIMA(0,1,2)(0,0,0)[12] intercept
# Total fit time: 7.211 seconds
# Processing Region XII - meat_chicken_whole
#
# Best model:  ARIMA(4,1,0)(0,0,0)[12] intercept
# Total fit time: 6.796 seconds
# Processing Region XII - meat_pork
#
# Best model:  ARIMA(0,1,3)(2,0,0)[12] intercept
# Total fit time: 7.680 seconds
# Processing Region XII - onions
#
# Best model:  ARIMA(1,1,3)(1,0,0)[12] intercept
# Total fit time: 6.987 seconds
# Processing Region XII - potatoes
#
# Best model:  ARIMA(4,1,1)(0,0,0)[12] intercept
# Total fit time: 6.228 seconds
# Processing Region XII - rice
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 6.222 seconds
# Processing Region XII - tomatoes
#
# Best model:  ARIMA(2,1,1)(0,0,2)[12] intercept
# Total fit time: 6.124 seconds
# Processing Region XIII - beans
#
# Best model:  ARIMA(0,1,5)(0,0,0)[12] intercept
# Total fit time: 6.168 seconds
# Processing Region XIII - cabbage
#
# Best model:  ARIMA(5,1,0)(0,0,0)[12] intercept
# Total fit time: 9.204 seconds
# Processing Region XIII - carrots
#
# Best model:  ARIMA(2,1,1)(1,0,0)[12] intercept
# Total fit time: 6.745 seconds
# Processing Region XIII - eggs
#
# Best model:  ARIMA(0,1,2)(1,0,2)[12] intercept
# Total fit time: 8.984 seconds
# Processing Region XIII - meat_beef_chops
#
# Best model:  ARIMA(1,2,1)(1,0,0)[12]
# Total fit time: 6.452 seconds
# Processing Region XIII - meat_chicken_whole
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 6.833 seconds
# Processing Region XIII - meat_pork
#
# Best model:  ARIMA(1,1,0)(1,0,0)[12] intercept
# Total fit time: 6.890 seconds
# Processing Region XIII - onions
#
# Best model:  ARIMA(3,1,0)(2,0,0)[12] intercept
# Total fit time: 7.215 seconds
# Processing Region XIII - potatoes
#
# Best model:  ARIMA(3,1,0)(2,0,0)[12] intercept
# Total fit time: 5.881 seconds
# Processing Region XIII - rice
#
# Best model:  ARIMA(0,1,4)(1,0,0)[12] intercept
# Total fit time: 5.854 seconds
# Processing Region XIII - tomatoes
#
# Best model:  ARIMA(0,1,4)(0,0,0)[12] intercept
# Total fit time: 6.732 seconds
# Forecasts saved to forecasts.csv
